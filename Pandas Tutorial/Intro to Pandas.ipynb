# %% [markdown]
# # DAT - Pandas Tutorial
# ### An introduction to some basic concepts.

# %% [markdown]
# |========================================================================================================================|

# %% [markdown]
# ## Importing the library and the dataset:

# %%
import pandas as pd

# %% [markdown]
# This is the very first step for creating any Python data analysis project.

# %%
df = pd.read_csv("C:/Users/Alex/DataScience/DAT/Datasets/Titanic/train.csv", header=0)
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %% [markdown]
# The function __pd.read_csv()__ translates a comma seperated values file (csv file) into a pandas dataframe. The header attribute defines the row to be considered as the header of the dataset - default is 0.
#
# The function __df.head(6)__ displays the first 6 arrays of the dataframe - default is 5.

# %% [markdown]
# ### Reading and manipulating the dataframe:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %% [markdown]
# __df.info()__ shows some basic information about each column of the dataframe. Non-null values count and data type of elements for each column are included in the display.

# %% [markdown]
# Showing the first contents of the Cabin column:

# %%
df["Cabin"].head()
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# Name: Cabin, dtype: object

# %% [markdown]
# Selecting the passengers that were at the Age of 30:

# %%
df[df["Age"]==30]
# Out:
#      PassengerId  Survived  Pclass  \
# 79            80         1       3
# 157          158         0       3
# 178          179         0       2
# 213          214         0       2
# 219          220         0       2
# 244          245         0       3
# 253          254         0       3
# 257          258         1       1
# 286          287         1       3
# 308          309         0       2
# 309          310         1       1
# 322          323         1       2
# 365          366         0       3
# 418          419         0       2
# 452          453         0       1
# 488          489         0       3
# 520          521         1       1
# 534          535         0       3
# 537          538         1       1
# 606          607         0       3
# 726          727         1       2
# 747          748         1       2
# 798          799         0       3
# 799          800         0       3
# 842          843         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 79                            Dowdell, Miss. Elizabeth  female  30.0      0
# 157                                    Corn, Mr. Harry    male  30.0      0
# 178                                 Hale, Mr. Reginald    male  30.0      0
# 213                        Givard, Mr. Hans Kristensen    male  30.0      0
# 219                                 Harris, Mr. Walter    male  30.0      0
# 244                               Attalah, Mr. Sleiman    male  30.0      0
# 253                           Lobb, Mr. William Arthur    male  30.0      1
# 257                               Cherry, Miss. Gladys  female  30.0      0
# 286                            de Mulder, Mr. Theodore    male  30.0      0
# 308                                Abelson, Mr. Samuel    male  30.0      1
# 309                     Francatelli, Miss. Laura Mabel  female  30.0      0
# 322                          Slayter, Miss. Hilda Mary  female  30.0      0
# 365                     Adahl, Mr. Mauritz Nils Martin    male  30.0      0
# 418                         Matthews, Mr. William John    male  30.0      0
# 452                    Foreman, Mr. Benjamin Laventall    male  30.0      0
# 488                      Somerton, Mr. Francis William    male  30.0      0
# 520                              Perreault, Miss. Anne  female  30.0      0
# 534                                Cacic, Miss. Marija  female  30.0      0
# 537                                LeRoy, Miss. Bertha  female  30.0      0
# 606                                  Karaic, Mr. Milan    male  30.0      0
# 726        Renouf, Mrs. Peter Henry (Lillian Jefferys)  female  30.0      3
# 747                              Sinkkonen, Miss. Anna  female  30.0      0
# 798                       Ibrahim Shawah, Mr. Yousseff    male  30.0      0
# 799  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...  female  30.0      1
# 842                            Serepeca, Miss. Augusta  female  30.0      0
#
#      Parch           Ticket      Fare Cabin Embarked
# 79       0           364516   12.4750   NaN        S
# 157      0  SOTON/OQ 392090    8.0500   NaN        S
# 178      0           250653   13.0000   NaN        S
# 213      0           250646   13.0000   NaN        S
# 219      0        W/C 14208   10.5000   NaN        S
# 244      0             2694    7.2250   NaN        C
# 253      0        A/5. 3336   16.1000   NaN        S
# 257      0           110152   86.5000   B77        S
# 286      0           345774    9.5000   NaN        S
# 308      0        P/PP 3381   24.0000   NaN        C
# 309      0         PC 17485   56.9292   E36        C
# 322      0           234818   12.3500   NaN        Q
# 365      0           C 7076    7.2500   NaN        S
# 418      0            28228   13.0000   NaN        S
# 452      0           113051   27.7500  C111        C
# 488      0       A.5. 18509    8.0500   NaN        S
# 520      0            12749   93.5000   B73        S
# 534      0           315084    8.6625   NaN        S
# 537      0         PC 17761  106.4250   NaN        C
# 606      0           349246    7.8958   NaN        S
# 726      0            31027   21.0000   NaN        S
# 747      0           250648   13.0000   NaN        S
# 798      0             2685    7.2292   NaN        C
# 799      1           345773   24.1500   NaN        S
# 842      0           113798   31.0000   NaN        C

# %% [markdown]
# Selecting the passengers that paid more than 10 GBP:

# %%
df[df["Fare"]>10]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch      Ticket     Fare Cabin Embarked
# 1        0    PC 17599  71.2833   C85        C
# 3        0      113803  53.1000  C123        S
# 6        0       17463  51.8625   E46        S
# 7        1      349909  21.0750   NaN        S
# 8        2      347742  11.1333   NaN        S
# ..     ...         ...      ...   ...      ...
# 885      5      382652  29.1250   NaN        Q
# 886      0      211536  13.0000   NaN        S
# 887      0      112053  30.0000   B42        S
# 888      2  W./C. 6607  23.4500   NaN        S
# 889      0      111369  30.0000  C148        C
#
# [555 rows x 12 columns]

# %% [markdown]
# Selecting the passengers that were both female and were on 1st class:

# %%
df[(df["Sex"]=="female") & (df["Pclass"]==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833   C85        C
# 3        0    113803   53.1000  C123        S
# 11       0    113783   26.5500  C103        S
# 31       0  PC 17569  146.5208   B78        C
# 52       0  PC 17572   76.7292   D33        C
# ..     ...       ...       ...   ...      ...
# 856      1     36928  164.8667   NaN        S
# 862      0     17466   25.9292   D17        S
# 871      1     11751   52.5542   D35        S
# 879      1     11767   83.1583   C50        C
# 887      0    112053   30.0000   B42        S
#
# [94 rows x 12 columns]

# %% [markdown]
# Selecting the passengers whose name included 'Helen':

# %%
df[df["Name"].str.contains('Helen')]
# Out:
#      PassengerId  Survived  Pclass  \
# 88            89         1       1
# 136          137         1       1
# 208          209         1       3
# 254          255         0       3
# 291          292         1       1
# 297          298         0       1
# 299          300         1       1
# 359          360         1       3
# 469          470         1       3
# 888          889         0       3
#
#                                                 Name     Sex    Age  SibSp  \
# 88                        Fortune, Miss. Mabel Helen  female  23.00      3
# 136                     Newsom, Miss. Helen Monypeny  female  19.00      0
# 208                        Carr, Miss. Helen "Ellen"  female  16.00      0
# 254         Rosblom, Mrs. Viktor (Helena Wilhelmina)  female  41.00      0
# 291          Bishop, Mrs. Dickinson H (Helen Walton)  female  19.00      1
# 297                     Allison, Miss. Helen Loraine  female   2.00      1
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.00      0
# 359                Mockler, Miss. Helen Mary "Ellie"  female    NaN      0
# 469                    Baclini, Miss. Helene Barbara  female   0.75      2
# 888         Johnston, Miss. Catherine Helen "Carrie"  female    NaN      1
#
#      Parch      Ticket      Fare        Cabin Embarked
# 88       2       19950  263.0000  C23 C25 C27        S
# 136      2       11752   26.2833          D47        S
# 208      0      367231    7.7500          NaN        Q
# 254      2      370129   20.2125          NaN        S
# 291      0       11967   91.0792          B49        C
# 297      2      113781  151.5500      C22 C26        S
# 299      1    PC 17558  247.5208      B58 B60        C
# 359      0      330980    7.8792          NaN        Q
# 469      1        2666   19.2583          NaN        C
# 888      2  W./C. 6607   23.4500          NaN        S

# %% [markdown]
# Selecting specific rows from the dataframe:

# %%
df.iloc[[2,3]]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
#
#              Ticket    Fare Cabin Embarked
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S

# %% [markdown]
# Finding the passengers whose Age attribute is missing and displaying the first 5 of them:

# %%
df[df["Age"].isna()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %% [markdown]
# Getting the index values of selected rows (or of a dataframe in general):

# %%
df[df["Age"].isna()].index
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %% [markdown]
# All of the above functions return a pandas dataframe. Instead of just displaying it, we can store it as a new dataframe:

# %%
df_NoAge = df[df["Age"].isna()]
df_NoAge.head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %% [markdown]
# Setting a column as an index:

# %%
df_NoAge.set_index("PassengerId", drop=True).head()
# Out:
#              Survived  Pclass                           Name     Sex  Age  \
# PassengerId
# 6                   0       3               Moran, Mr. James    male  NaN
# 18                  1       2   Williams, Mr. Charles Eugene    male  NaN
# 20                  1       3        Masselmani, Mrs. Fatima  female  NaN
# 27                  0       3        Emir, Mr. Farred Chehab    male  NaN
# 29                  1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#              SibSp  Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 6                0      0  330877   8.4583   NaN        Q
# 18               0      0  244373  13.0000   NaN        S
# 20               0      0    2649   7.2250   NaN        C
# 27               0      0    2631   7.2250   NaN        C
# 29               0      0  330959   7.8792   NaN        Q

# %% [markdown]
# The drop attribute is used to delete the old indexes. If not included in the function, the old indexes would be stored as a new column in the dataframe.

# %% [markdown]
# Shape (Rows and Columns) of a data frame:

# %%
df_NoAge.shape
# Out:
# (177, 12)

# %% [markdown]
# Reseting the indexes:

# %%
df_NoAge.reset_index().head()
# Out:
#    index  PassengerId  Survived  Pclass                           Name  \
# 0      5            6         0       3               Moran, Mr. James
# 1     17           18         1       2   Williams, Mr. Charles Eugene
# 2     19           20         1       3        Masselmani, Mrs. Fatima
# 3     26           27         0       3        Emir, Mr. Farred Chehab
# 4     28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"
#
#       Sex  Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 0    male  NaN      0      0  330877   8.4583   NaN        Q
# 1    male  NaN      0      0  244373  13.0000   NaN        S
# 2  female  NaN      0      0    2649   7.2250   NaN        C
# 3    male  NaN      0      0    2631   7.2250   NaN        C
# 4  female  NaN      0      0  330959   7.8792   NaN        Q

# %% [markdown]
# Keep in mind that the reset_index function sorts the indexes but leaves the old indexes as a column in the dataframe. To counter this, we use the attribute drop:

# %%
df_NoAge.reset_index(drop=True, inplace = True)
df_NoAge.head()
# Out:
#    PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 0            6         0       3               Moran, Mr. James    male  NaN
# 1           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 2           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 3           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 4           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#    SibSp  Parch  Ticket     Fare Cabin Embarked
# 0      0      0  330877   8.4583   NaN        Q
# 1      0      0  244373  13.0000   NaN        S
# 2      0      0    2649   7.2250   NaN        C
# 3      0      0    2631   7.2250   NaN        C
# 4      0      0  330959   7.8792   NaN        Q

# %% [markdown]
# Note that we also used the attribute inplace. This indicates that instead of returning a modified pandas dataframe, the function is directly modifying the dataframe it applies on. Keep this in mind, because most of the functions pandas uses to manipulate a dataframe do have an inplace attribute.

# %% [markdown]
# Speaking about Drop, we can use df.drop to delete certain rows or columns from the dataframe:

# %%
df_NoAge.drop(["Age"], axis = 1, inplace=True)
df_NoAge.drop([2,3], inplace=True)
df_NoAge.head()
# Out:
# c:\users\alex\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    PassengerId  Survived  Pclass  \
# 0            6         0       3
# 1           18         1       2
# 4           29         1       3
# 5           30         0       3
# 6           32         1       1
#
#                                              Name     Sex  SibSp  Parch  \
# 0                                Moran, Mr. James    male      0      0
# 1                    Williams, Mr. Charles Eugene    male      0      0
# 4                   O'Dwyer, Miss. Ellen "Nellie"  female      0      0
# 5                             Todoroff, Mr. Lalio    male      0      0
# 6  Spencer, Mrs. William Augustus (Marie Eugenie)  female      1      0
#
#      Ticket      Fare Cabin Embarked
# 0    330877    8.4583   NaN        Q
# 1    244373   13.0000   NaN        S
# 4    330959    7.8792   NaN        Q
# 5    349216    7.8958   NaN        S
# 6  PC 17569  146.5208   B78        C

# %% [markdown]
# The attribute axis is used to determine if you are droping rows (0 - default) or columns (1).

# %% [markdown]
# Adding a new row in the dataframe:

# %%
df_NoAge.append({'Survived':0, 'Name':'Unknown Artist'}, ignore_index=True).tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 171        864.0         0     3.0         Sage, Miss. Dorothy Edith "Dolly"
# 172        869.0         0     3.0               van Melkebeke, Mr. Philemon
# 173        879.0         0     3.0                        Laleff, Mr. Kristo
# 174        889.0         0     3.0  Johnston, Miss. Catherine Helen "Carrie"
# 175          NaN         0     NaN                            Unknown Artist
#
#         Sex  SibSp  Parch      Ticket     Fare Cabin Embarked
# 171  female    8.0    2.0    CA. 2343  69.5500   NaN        S
# 172    male    0.0    0.0      345777   9.5000   NaN        S
# 173    male    0.0    0.0      349217   7.8958   NaN        S
# 174  female    1.0    2.0  W./C. 6607  23.4500   NaN        S
# 175     NaN    NaN    NaN         NaN      NaN   NaN      NaN

# %%
df_NoAge.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 172          860         0       3                          Razi, Mr. Raihed
# 173          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 174          869         0       3               van Melkebeke, Mr. Philemon
# 175          879         0       3                        Laleff, Mr. Kristo
# 176          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  SibSp  Parch      Ticket     Fare Cabin Embarked
# 172    male      0      0        2629   7.2292   NaN        C
# 173  female      8      2    CA. 2343  69.5500   NaN        S
# 174    male      0      0      345777   9.5000   NaN        S
# 175    male      0      0      349217   7.8958   NaN        S
# 176  female      1      2  W./C. 6607  23.4500   NaN        S

# %% [markdown]
# Those attributes that were not defined are saved as NaN values. Also note that the tail function is the direct opposite of the head function.

# %% [markdown]
# ### Advanced manipulation functions

# %% [markdown]
# Mean, median, quantile, min and max:

# %%
df_NoAge["Fare"].mean()
# Out:
# 22.329236

# %%
df_NoAge["Fare"].median()
# Out:
# 8.05

# %%
df_NoAge["Fare"].quantile()
# Out:
# 8.05

# %%
df_NoAge["Fare"].min()
# Out:
# 0.0

# %%
df_NoAge["Fare"].max()
# Out:
# 227.525

# %% [markdown]
# Returns the unique values of a column:

# %%
df_NoAge["Fare"].unique()
# Out:
# array([  8.4583,  13.    ,   7.8792,   7.8958, 146.5208,   7.75  ,
#          7.2292,   8.05  ,  15.5   ,  21.6792,  35.5   ,  27.7208,
#         15.2458,   7.7875,   7.775 ,  24.15  ,  22.3583,   7.3125,
#          8.6625,  69.55  ,  55.    ,  25.925 ,  25.4667,  15.05  ,
#         50.    ,   7.55  ,  14.4542,   7.25  ,  79.2   ,  31.    ,
#          0.    ,  26.    ,  30.5   ,  23.25  ,  12.35  , 110.8833,
#        133.65  ,  16.1   ,  35.    ,   7.225 ,  82.1708,   7.7292,
#          6.8583,   8.1125,  19.9667,  51.8625,   7.725 ,  52.    ,
#         14.4583,  15.1   ,   7.6292,  26.55  , 221.7792,  14.5   ,
#         13.8625,   7.8292, 227.525 ,   8.7125,  33.    ,  42.4   ,
#          7.05  ,   7.7333,  56.4958,   8.1375,   7.7375,  30.    ,
#         39.6   ,  23.45  ,  30.6958,   6.95  ,  29.7   ,  89.1042,
#          9.5   ])

# %% [markdown]
# Counting and summing a column's values:

# %%
df_NoAge["Fare"].count()
# Out:
# 175

# %%
df_NoAge["Fare"].sum()
# Out:
# 3907.6163

# %% [markdown]
# Finding most common value of column:

# %%
df_NoAge["Fare"].mode()
# Out:
# 0    7.75
# dtype: float64

# %% [markdown]
# Sorting the dataframe by a column's values:

# %%
df_NoAge.sort_values(by='Fare', ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass  \
# 114          558         0       1
# 108          528         0       1
# 6             32         1       1
# 65           335         1       1
# 62           307         1       1
#
#                                                   Name     Sex  SibSp  Parch  \
# 114                                Robbins, Mr. Victor    male      0      0
# 108                                 Farthing, Mr. John    male      0      0
# 6       Spencer, Mrs. William Augustus (Marie Eugenie)  female      1      0
# 65   Frauenthal, Mrs. Henry William (Clara Heinshei...  female      1      0
# 62                             Fleming, Miss. Margaret  female      0      0
#
#        Ticket      Fare Cabin Embarked
# 114  PC 17757  227.5250   NaN        C
# 108  PC 17483  221.7792   C95        S
# 6    PC 17569  146.5208   B78        C
# 65   PC 17611  133.6500   NaN        S
# 62      17421  110.8833   NaN        C

# %% [markdown]
# Sorting by and selecting certain columns to display:

# %%
df_NoAge.sort_values(['Pclass', 'Fare'], ascending=[True,False])[['Pclass', 'Fare']].head(6)
# Out:
#      Pclass      Fare
# 114       1  227.5250
# 108       1  221.7792
# 6         1  146.5208
# 65        1  133.6500
# 62        1  110.8833
# 171       1   89.1042

# %% [markdown]
# Group a column's values with the values of another column (In this case we are grouping the values of Pclass with the mean values of the Fare corresponding to those Pclasses):

# %%
df_NoAge.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    60.551940
# 2     7.932955
# 3    14.953699
# Name: Fare, dtype: float64

# %% [markdown]
# Mapping a column's values:

# %%
df_NoAge['Pclass'].map(lambda x: str(x)+"st Class").head()
# Out:
# 0    3st Class
# 1    2st Class
# 4    3st Class
# 5    3st Class
# 6    1st Class
# Name: Pclass, dtype: object

# %% [markdown]
# Similar with mapping:

# %%
df_NoAge["PassengerId"].apply(lambda x: x/100).head()
# Out:
# 0    0.06
# 1    0.18
# 4    0.29
# 5    0.30
# 6    0.32
# Name: PassengerId, dtype: float64

# %%
df_NoAge["Name"].iloc[1:3].apply(lambda x: x+" HELLO THERE")
# Out:
# 1     Williams, Mr. Charles Eugene HELLO THERE
# 4    O'Dwyer, Miss. Ellen "Nellie" HELLO THERE
# Name: Name, dtype: object

# %% [markdown]
# The apply function can even manipulate single elements of the dataframe.

# %% [markdown]
# Examples of creating a new column:

# %%
df_NoAge["New"] = df_NoAge["Name"] + df_NoAge["Embarked"]
df_NoAge.head()
# Out:
# c:\users\alex\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    PassengerId  Survived  Pclass  \
# 0            6         0       3
# 1           18         1       2
# 4           29         1       3
# 5           30         0       3
# 6           32         1       1
#
#                                              Name     Sex  SibSp  Parch  \
# 0                                Moran, Mr. James    male      0      0
# 1                    Williams, Mr. Charles Eugene    male      0      0
# 4                   O'Dwyer, Miss. Ellen "Nellie"  female      0      0
# 5                             Todoroff, Mr. Lalio    male      0      0
# 6  Spencer, Mrs. William Augustus (Marie Eugenie)  female      1      0
#
#      Ticket      Fare Cabin Embarked  \
# 0    330877    8.4583   NaN        Q
# 1    244373   13.0000   NaN        S
# 4    330959    7.8792   NaN        Q
# 5    349216    7.8958   NaN        S
# 6  PC 17569  146.5208   B78        C
#
#                                                New
# 0                                Moran, Mr. JamesQ
# 1                    Williams, Mr. Charles EugeneS
# 4                   O'Dwyer, Miss. Ellen "Nellie"Q
# 5                             Todoroff, Mr. LalioS
# 6  Spencer, Mrs. William Augustus (Marie Eugenie)C

# %%
df_NoAge["New"] = df_NoAge["Survived"].apply(lambda x: "Dead" if (x==0) else "Alive")
df_NoAge.head()
# Out:
# c:\users\alex\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    PassengerId  Survived  Pclass  \
# 0            6         0       3
# 1           18         1       2
# 4           29         1       3
# 5           30         0       3
# 6           32         1       1
#
#                                              Name     Sex  SibSp  Parch  \
# 0                                Moran, Mr. James    male      0      0
# 1                    Williams, Mr. Charles Eugene    male      0      0
# 4                   O'Dwyer, Miss. Ellen "Nellie"  female      0      0
# 5                             Todoroff, Mr. Lalio    male      0      0
# 6  Spencer, Mrs. William Augustus (Marie Eugenie)  female      1      0
#
#      Ticket      Fare Cabin Embarked    New
# 0    330877    8.4583   NaN        Q   Dead
# 1    244373   13.0000   NaN        S  Alive
# 4    330959    7.8792   NaN        Q  Alive
# 5    349216    7.8958   NaN        S   Dead
# 6  PC 17569  146.5208   B78        C  Alive

# %% [markdown]
# Hope this was helpful! Have you found what you were searching for? If not, __google it__!
